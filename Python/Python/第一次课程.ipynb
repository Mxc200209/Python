# %% [markdown]
# # Python第一次课程
# Author: 马欣驰
#
# Date: 2021年9月6日
#
# 导入数据

# %% [markdown]
# ## 导入数据

# %%
# 功能性代码区域
import pandas as pd # panda是最常用的模块之一
import numpy as np

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all' #让jupyter notebook输出所有结果 代码7

#pd.set_option('display.max_cloumns',None)

# %%
# 这里是导入数据的代码
# 复制路径 C:\Users\hp\Desktop\Python\Python-1\000001.csv
# 复制相对路径 000001.csv 注意区分/与\
data = pd.read_csv('000001.csv')
data # 7724*8
# Out:
#              Day  Preclose     Open  Highest   Lowest    Close       Volume  \
# 0     1990/12/19              96.05    99.98    95.79    99.98       126000
# 1     1990/12/20     99.98   104.30   104.39    99.98   104.39        19700
# 2     1990/12/21    104.39   109.07   109.13   103.73   109.13         2800
# 3     1990/12/24    109.13   113.57   114.55   109.13   114.55         3200
# 4     1990/12/25    114.55   120.09   120.25   114.55   120.25         1500
# ...          ...       ...      ...      ...      ...      ...          ...
# 7719   2022/7/25   3269.97  3269.71  3273.18  3243.03  3250.39  27124574400
# 7720   2022/7/26   3250.39  3254.19  3282.41  3246.04  3277.44  25946867600
# 7721   2022/7/27   3277.44  3271.78  3282.57  3265.73  3275.76  24913148500
# 7722   2022/7/28   3275.76  3287.50  3305.71  3277.11  3282.58  28805505600
# 7723   2022/7/29   3282.58  3282.81  3294.80  3246.37  3253.24  30733104700
#
#              Money
# 0     4.940000e+05
# ...

# %%
data = pd.read_csv('000001.csv')
print(data) # 数据打印出来的样子
# Out:
#              Day  Preclose     Open  Highest   Lowest    Close       Volume  \
# 0     1990/12/19              96.05    99.98    95.79    99.98       126000
# 1     1990/12/20     99.98   104.30   104.39    99.98   104.39        19700
# 2     1990/12/21    104.39   109.07   109.13   103.73   109.13         2800
# 3     1990/12/24    109.13   113.57   114.55   109.13   114.55         3200
# 4     1990/12/25    114.55   120.09   120.25   114.55   120.25         1500
# ...          ...       ...      ...      ...      ...      ...          ...
# 7719   2022/7/25   3269.97  3269.71  3273.18  3243.03  3250.39  27124574400
# 7720   2022/7/26   3250.39  3254.19  3282.41  3246.04  3277.44  25946867600
# 7721   2022/7/27   3277.44  3271.78  3282.57  3265.73  3275.76  24913148500
# 7722   2022/7/28   3275.76  3287.50  3305.71  3277.11  3282.58  28805505600
# 7723   2022/7/29   3282.58  3282.81  3294.80  3246.37  3253.24  30733104700
#
#              Money
# 0     4.940000e+05
# ...

# %%
# 仅做示范，不建议使用
data = pd.read_csv('000001.csv')
data
print(data)
# Out:
#              Day  Preclose     Open  Highest   Lowest    Close       Volume  \
# 0     1990/12/19              96.05    99.98    95.79    99.98       126000
# 1     1990/12/20     99.98   104.30   104.39    99.98   104.39        19700
# 2     1990/12/21    104.39   109.07   109.13   103.73   109.13         2800
# 3     1990/12/24    109.13   113.57   114.55   109.13   114.55         3200
# 4     1990/12/25    114.55   120.09   120.25   114.55   120.25         1500
# ...          ...       ...      ...      ...      ...      ...          ...
# 7719   2022/7/25   3269.97  3269.71  3273.18  3243.03  3250.39  27124574400
# 7720   2022/7/26   3250.39  3254.19  3282.41  3246.04  3277.44  25946867600
# 7721   2022/7/27   3277.44  3271.78  3282.57  3265.73  3275.76  24913148500
# 7722   2022/7/28   3275.76  3287.50  3305.71  3277.11  3282.58  28805505600
# 7723   2022/7/29   3282.58  3282.81  3294.80  3246.37  3253.24  30733104700
#
#              Money
# 0     4.940000e+05
# ...

# %% [markdown]
# ## 命名规则
# - 不能以数字开头
# - 可以用字母、下划线
# - 注意大小写 SAS不区分、R区分
# - 不能是关键字 一些函数的名字 read_csv plt True False 真假 return
# - data1 是股票上证指数数据从1990-2022年7月

# %%
'''
这里随便写注释，接下来我们开始处理数据
可以单引号双引号交替使用
'''

# %%
help(pd.read_csv)
# pd.read_csv? 或 Ctrl+点击文件名
# Out:
# Help on function read_csv in module pandas.io.parsers.readers:
#
# ...

# %%
type(data) #dataframe-数据框
# Out:
# pandas.core.frame.DataFrame

# %%
type(data['Close']) # series-序列数据；time-series 时间序列
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## 选择数据框的某一列

# %%
data['Close']
# Out:
# 0         99.98
# 1        104.39
# 2        109.13
# 3        114.55
# 4        120.25
#          ...
# 7719    3250.39
# 7720    3277.44
# 7721    3275.76
# 7722    3282.58
# 7723    3253.24
# Name: Close, Length: 7724, dtype: float64

# %%
data[['Close']]
# Out:
#         Close
# 0       99.98
# 1      104.39
# 2      109.13
# 3      114.55
# 4      120.25
# ...       ...
# 7719  3250.39
# 7720  3277.44
# 7721  3275.76
# 7722  3282.58
# 7723  3253.24
#
# [7724 rows x 1 columns]

# %%
type(data[['Close']])
# Out:
# pandas.core.frame.DataFrame

# %%
data[['Day','Close','Money']]
# Out:
#              Day    Close         Money
# 0     1990/12/19    99.98  4.940000e+05
# 1     1990/12/20   104.39  8.400000e+04
# 2     1990/12/21   109.13  1.600000e+04
# 3     1990/12/24   114.55  3.100000e+04
# 4     1990/12/25   120.25  6.000000e+03
# ...          ...      ...           ...
# 7719   2022/7/25  3250.39  3.480000e+11
# 7720   2022/7/26  3277.44  3.340000e+11
# 7721   2022/7/27  3275.76  3.400000e+11
# 7722   2022/7/28  3282.58  3.960000e+11
# 7723   2022/7/29  3253.24  4.110000e+11
#
# [7724 rows x 3 columns]

# %% [markdown]
# ## 选择数据框的某一行

# %%
# Python的数据开始的序号都是0
data[0:11]
# 所需行数+1
# Out:
#            Day  Preclose    Open  Highest  Lowest   Close  Volume     Money
# 0   1990/12/19             96.05    99.98   95.79   99.98  126000  494000.0
# 1   1990/12/20     99.98  104.30   104.39   99.98  104.39   19700   84000.0
# 2   1990/12/21    104.39  109.07   109.13  103.73  109.13    2800   16000.0
# 3   1990/12/24    109.13  113.57   114.55  109.13  114.55    3200   31000.0
# 4   1990/12/25    114.55  120.09   120.25  114.55  120.25    1500    6000.0
# 5   1990/12/26    120.25  125.27   125.27  120.25  125.27   10000   53000.0
# 6   1990/12/27    125.27  125.27   125.28  125.27  125.28    6600  104000.0
# 7   1990/12/28    125.28  126.39   126.45  125.28  126.45   10800   88000.0
# 8   1990/12/31    126.45  126.56   127.61  126.48  127.61    7800   60000.0
# 9     1991/1/2    127.61  127.61   128.84  127.61  128.84    9100   59000.0
# 10    1991/1/3    128.84  128.84   130.14  128.84  130.14   14100   93000.0

# %% [markdown]
# 数据样本是从1990-2022年7月
#
# 看看2008年的股票上证指数
#
# # 把Day这一列1990/12/19 这种格式的数据转换成日期格式

# %%
data['Day'] = pd.to_datetime(data['Day'], format = '%Y/%m/%d')
data
# format形式一定要对应原始数据的样子 1990/12/19 %Y%m%d 1990-12-19 %Y-%m-%d 年份大写
# %h %m %s
# Out:
#             Day  Preclose     Open  Highest   Lowest    Close       Volume  \
# 0    1990-12-19              96.05    99.98    95.79    99.98       126000
# 1    1990-12-20     99.98   104.30   104.39    99.98   104.39        19700
# 2    1990-12-21    104.39   109.07   109.13   103.73   109.13         2800
# 3    1990-12-24    109.13   113.57   114.55   109.13   114.55         3200
# 4    1990-12-25    114.55   120.09   120.25   114.55   120.25         1500
# ...         ...       ...      ...      ...      ...      ...          ...
# 7719 2022-07-25   3269.97  3269.71  3273.18  3243.03  3250.39  27124574400
# 7720 2022-07-26   3250.39  3254.19  3282.41  3246.04  3277.44  25946867600
# 7721 2022-07-27   3277.44  3271.78  3282.57  3265.73  3275.76  24913148500
# 7722 2022-07-28   3275.76  3287.50  3305.71  3277.11  3282.58  28805505600
# 7723 2022-07-29   3282.58  3282.81  3294.80  3246.37  3253.24  30733104700
#
#              Money
# 0     4.940000e+05
# 1     8.400000e+04
# ...

# %% [markdown]
# ## 设置索引 index

# %%
data.set_index('Day',inplace = True)
data
# Out:
#             Preclose     Open  Highest   Lowest    Close       Volume  \
# Day
#